# %%
import pandas as pd #!

df_p48 = pd.read_excel('../../../data/p48_2022.xlsx', index_col=0, parse_dates=True)
df_p48
# Out:
#                      Turbinación bombeo  Nuclear  Ciclo combinado  \
# datetime
# 2022-01-01 00:00:00              50.000  6096.70          1885.40
# 2022-01-01 01:00:00               0.000  6098.60          1948.80
# 2022-01-01 02:00:00               0.000  6097.70          1937.90
# 2022-01-01 03:00:00               0.000  6096.70          1785.80
# 2022-01-01 04:00:00               0.000  6097.70          1785.60
# ...                                 ...      ...              ...
# 2022-12-31 19:00:00            2282.800  6454.00          1151.00
# 2022-12-31 20:00:00            2170.800  6456.75          1332.00
# 2022-12-31 21:00:00            1454.775  6452.30          1563.10
# 2022-12-31 22:00:00             823.625  6457.75          1725.00
# 2022-12-31 23:00:00             134.500  1604.80           526.45
#
#                      Solar fotovoltaica  Solar térmica  Consumo bombeo  \
# datetime
# 2022-01-01 00:00:00                 7.1           10.0        -1243.00
# ...

# %%
df_p48.resample('ME').sum().plot.bar()
# Out:
# <Axes: xlabel='datetime'>
